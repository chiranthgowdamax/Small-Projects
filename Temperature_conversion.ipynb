# %% [markdown]
# <a href="https://colab.research.google.com/github/chiranthgowdamax/Small-Projects/blob/main/Temperature_conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
temp = float(input("Enter the Temperature: "))
unit = input("Is this Temperature is in Celsius or Fahrenheit (C/F):")

if unit == "C":
  temp = round((temp*9/5)+32, 1)
  print(f"The Temperature in Fahrenheit: {temp}°F")
elif unit == "F":
  temp = round((temp - 32)*5/9, 1)
  print(f"The Temperature in Celsius: {temp}°C")
else:
  print(f"{unit} is an invalid unit of measurement")
# Out:
# Enter the Temperature: 100
# Is this Temperature is in Celsius or Fahrenheit (C/F):F
# The Temperature in Celsius: 37.8°C
