# %% [markdown]
# <a href="https://colab.research.google.com/github/chiranthgowdamax/Small-Projects/blob/main/Better_Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = float(input("Enter first number:"))
op = input("Enter an operation(+,-,*,/)")
num2 = float(input("Enter second number:"))

if op == "+":
  print(f"{num1} + {num2} ={num1+num2}")
elif op == "-":
  print(f"{num1} - {num2} ={num1-num2}")
elif op == "*":
  print(f"{num1} * {num2} ={num1*num2}")
elif op == "/":
  print(f"{num1} / {num2} ={num1/num2}")
else:
  print("Invalid Operator")
# Out:
# Enter first number:9
# Enter an operation(+,-,*,/)&
# Enter second number:88
# Invalid Operator
