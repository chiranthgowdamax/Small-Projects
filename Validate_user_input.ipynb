# %% [markdown]
# <a href="https://colab.research.google.com/github/chiranthgowdamax/Small-Projects/blob/main/Validate_user_input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
username = input("Enter the username: ")
length = len(username)
# username is no more than 12 characters

if length > 12:
  print("Username limit exceeded (12 characters allowed.")
else:
  pass

# username must not contain spaces

if not username.find(" ") == -1:
  print("Spaces are not allowed")
else:
  pass

# username must not contain digits

if not username.isalpha():
  print("Your username must contain digits")
else:
  print(f"Welcome {username} !!")
