# %% [markdown]
# <a href="https://colab.research.google.com/github/chiranthgowdamax/Small-Projects/blob/main/Madlibs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mad libs
adj = input("Enter an Adjective: ")
noun = input("Enter a Noun: ")
adj1 = input("Enter an Adjective: ")
verb = input("Enter a Verb: ")
adj3 = input("Enter an Adjective: ")

print(f"Today is went to {adj} zoo.")
print(f"In an exhibit. I saw {noun}")
print(f"{noun} was {adj1} and {verb}ing")
print(f"I was {adj3}")
# Out:
# Enter an Adjective: Horror
# Enter a Noun: Elon
# Enter an Adjective: Serious
# Enter a Verb: Fap
# Enter an Adjective: Sexy
# Today is went to Horror  zoo.
# In an exhibit. I saw Elon
# Elon was Serious and Faping
# I was Sexy
