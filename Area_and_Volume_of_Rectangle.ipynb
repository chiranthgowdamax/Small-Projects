# %% [markdown]
# <a href="https://colab.research.google.com/github/chiranthgowdamax/Small-Projects/blob/main/Area_and_Volume_of_Rectangle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("---AREA OF RECTANGLE---")
print(" ")
select = input("Area or Volume (A/V): ")

if select == "A":
  length = float(input("Enter the length: "))
  width = float(input("Enter the width: "))

  area = length * width

  print(f"The area of Rectangle: {area}")

elif select == "V":
  length = float(input("Enter the length: "))
  width = float(input("Enter the width: "))
  height = float(input("Enter the height: "))

  volume = length * width * height

  print(f"The volume of Rectangle: {volume}")

else:
  print(f"{select} is invalid")
