# %% [markdown]
# <a href="https://colab.research.google.com/github/chiranthgowdamax/Small-Projects/blob/main/Simple_Shopping_Cart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
item = input("What would you like to buy ?: ")
price = float(input("What is the price ?: "))
quantity = int(input("How many would you like ?: "))

total = price * quantity

print(f"You have bought {quantity} × {item}/s")
print(f"Your Total: ₹{total}")
# Out:
# What would you like to buy ?: Chicken Pasta
# What is the price ?: 180
# How many would you like ?: 2
# You have bought 2 × Chicken Pasta/s
# Your Total: ₹360.0
