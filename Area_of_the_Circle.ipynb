# %% [markdown]
# <a href="https://colab.research.google.com/github/chiranthgowdamax/Small-Projects/blob/main/Area_of_the_Circle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
print("---Area of Circle---")
print(" ")
r = float(input("Enter the radius of the circle: "))
p = math.pi
a = p * pow(r,2)

print(f"Area of the circle: {round(a, 2)}cm²")
# Out:
# ---Area of Circle---
